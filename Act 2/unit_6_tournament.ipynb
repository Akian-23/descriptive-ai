# %%
# Quick test
from battle_royale import load_student_agents

agents = load_student_agents("student_agents")
print(f"Loaded {len(agents)} agents successfully!")
for agent in agents:
    print(f"  - {agent.name}")
# Out:
# 📂 Loading student agents from: student_agents
# ...
#
# Found 1 Python files and 21 JSON files
#
# ✅ King kong                      from dougdahl_tournament_agent.py
# ✅ Trust Builder                  from alex_brown_agent.json (JSON)
# ✅ Relationship Keeper            from alex_singh_agent.json (JSON)
# ✅ Risk Manager                   from bailey_gonzalez_agent.json (JSON)
# ✅ Stable Cooperator              from casey_thomas_agent.json (JSON)
# ✅ Balanced Trader                from casey_wong_agent.json (JSON)
# ✅ Betrayal Detector              from elliot_lopez_agent.json (JSON)
# ✅ Game Theory Expert             from elliot_wong_agent.json (JSON)
# ✅ Strategic Dove                 from finley_lee_agent.json (JSON)
# ✅ Equilibrium Finder             from hayden_gonzalez_agent.json (JSON)
# ✅ Quick Retaliator               from hayden_smith_agent.json (JSON)
# ✅ Cooperative Hawk               from jesse_garcia_agent.json (JSON)
# ...

# %%
"""
Unit 6: Agent Battle Royale Tournament
"""

from battle_royale import run_battle_royale
import webbrowser
import os

print(" Starting Unit 6 Tournament...")
print("This will generate:")
print("  1. tournament_results.json (raw data)")
print("  2. tournament_dashboard.html (interactive explorer)")
print("  3. tournament_bracket.png (bracket image)")
print("\n" + "="*70 + "\n")


# Run tournament
bracket_champ, rr_tournament, all_agents = run_battle_royale(
    folder_path="student_agents",
    bracket_rounds=100,
    rr_rounds=100,
    num_tournaments=3,
    save_bracket=True
)

print("\n Done! Opening dashboard in browser...")

# Automatically open the HTML file in default browser
html_file = "tournament_dashboard.html"
if os.path.exists(html_file):
    file_path = os.path.abspath(html_file)
    webbrowser.open('file://' + file_path)
    print(f" Dashboard opened in browser!")
    print(f"   If it didn't open, manually open: {html_file}")
else:
    print(f" Could not find {html_file}")
# Out:
#  Starting Unit 6 Tournament...
# This will generate:
#   1. tournament_results.json (raw data)
#   2. tournament_dashboard.html (interactive explorer)
#   3. tournament_bracket.png (bracket image)
#
# ...
#
#
# ████████╗██╗  ██╗███████╗    ██╗   ██╗██╗  ████████╗██╗███╗   ███╗ █████╗ ████████╗███████╗
# ╚══██╔══╝██║  ██║██╔════╝    ██║   ██║██║  ╚══██╔══╝██║████╗ ████║██╔══██╗╚══██╔══╝██╔════╝
#    ██║   ███████║█████╗      ██║   ██║██║     ██║   ██║██╔████╔██║███████║   ██║   █████╗
#    ██║   ██╔══██║██╔══╝      ██║   ██║██║     ██║   ██║██║╚██╔╝██║██╔══██║   ██║   ██╔══╝
#    ██║   ██║  ██║███████╗    ╚██████╔╝███████╗██║   ██║██║ ╚═╝ ██║██║  ██║   ██║   ███████╗
#    ╚═╝   ╚═╝  ╚═╝╚══════╝     ╚═════╝ ╚══════╝╚═╝   ╚═╝╚═╝     ╚═╝╚═╝  ╚═╝   ╚═╝   ╚══════╝
#
#  █████╗  ██████╗ ███████╗███╗   ██╗████████╗    ██████╗  █████╗ ████████╗████████╗██╗     ███████╗
# ██╔══██╗██╔════╝ ██╔════╝████╗  ██║╚══██╔══╝    ██╔══██╗██╔══██╗╚══██╔══╝╚══██╔══╝██║     ██╔════╝
# ...

# %%
# ============================================================================
# REFLECTION QUESTIONS
# ============================================================================

print("\n" + "="*70)
print("📝 REFLECTION QUESTIONS FOR YOUR WRITEUP")
print("="*70)
print("""
Look at the "ALL STUDENT AGENTS" table above to find your ranking.

1. Tournament Performance Analysis
   - What was your agent's final rank?
   - How did you perform in bracket vs. round-robin?
   - Were the results similar or different? Why might that be?

2. Strategy Analysis
   - Look at the top 3 agents. What strategies do they use?
   - Compare them to your agent's strategy (your evolved genes)
   - What made the winning strategies successful?

3. Bracket vs. Round-Robin
   - Was the Bracket Champion the same as Round-Robin Champion?
   - If different, what does this teach you about tournament formats?
   - Which format better reflects true agent quality? Why?

4. Superlative Awards
   - Which superlative award did your agent win (if any)?
   - What trade-offs do different strategies make?
   - Would you rather have high win rate or high total score?

5. Generalization Lesson
   - Your agent was trained on 10 random opponents in Unit 5
   - It competed against 20+ agents here (most unseen)
   - How did this affect your agent's performance?
   - What would you change if you could redesign for THIS environment?

6. Game Theory Insights
   - Is there a "best" strategy that beats everyone?
   - Why or why not? (Hint: Think about opponent diversity)
   - What real-world situations mirror this tournament dynamic?

SUBMISSION: Write a 1-2 page reflection answering these questions.
Include your rank, total score, and what you learned about
evolutionary optimization and game theory.
""")

print("\n" + "="*70)
print("🎉 THANK YOU FOR PARTICIPATING!")
print("="*70)
# Out:
# ...
# 📝 REFLECTION QUESTIONS FOR YOUR WRITEUP
# ...
#
# Look at the "ALL STUDENT AGENTS" table above to find your ranking.
#
# 1. Tournament Performance Analysis
#    - What was your agent's final rank?
#    - How did you perform in bracket vs. round-robin?
#    - Were the results similar or different? Why might that be?
#
# 2. Strategy Analysis
#    - Look at the top 3 agents. What strategies do they use?
#    - Compare them to your agent's strategy (your evolved genes)
#    - What made the winning strategies successful?
#
# 3. Bracket vs. Round-Robin
#    - Was the Bracket Champion the same as Round-Robin Champion?
#    - If different, what does this teach you about tournament formats?
#    - Which format better reflects true agent quality? Why?
#
# 4. Superlative Awards
#    - Which superlative award did your agent win (if any)?
#    - What trade-offs do different strategies make?
#    - Would you rather have high win rate or high total score?
#
# 5. Generalization Lesson
# ...

# %% [markdown]
# In the comprehensive round-robin tournament, my agent, Stellar, earned 1st place with 10,385 points. Running every matchup three times gave a clear picture of consistency and Stellar’s approach of cooperating with cooperative opponents while retaliating against defectors proved highly effective. Interestingly, the bracket champion was Adaptive Survivor, which ranked 6th in the round-robin. This difference illustrates how tournament formats matter: single-elimination brackets reward agents that can win decisive, high-stakes matches but they don’t always reflect overall skill. Round-robin, by forcing agents to face every opponent multiple times, highlights sustained performance and adaptability, which I believe better reflects true agent quality in a competitive environment. Stellar’s balanced design was well-suited for this format, consistently earning points across a diverse set of opponents.
#
# Looking at the top three agents: Stellar, Relationship Keeper and King Kong, it’s clear there are multiple ways to succeed. Relationship Keeper, a Grudge Holder variant, never forgives betrayal, contributing to a very high win rate of 90.5% but its total points were slightly lower than Stellar’s. King Kong used a more aggressive, high-risk approach, cooperating only with highly cooperative opponents, which led to fewer wins but occasionally high scores. Stellar struck a balance: it cooperated when advantageous and retaliated when necessary, allowing it to maintain high points across all opponents. This demonstrates that adaptability and consistent point accumulation can outperform strategies focused solely on winning the most matches or taking extreme risks.
#
# The superlative awards highlighted interesting trade-offs in strategy. Adaptive Survivor earned Most Aggressive, winning fast and decisively, while Stable Cooperator was Most Cooperative, focusing on mutual gains but unable to dominate overall. Equilibrium Finder was recognized as Most Consistent, with a very predictable score pattern and also won Biggest Upset, defeating Stable Cooperator despite finishing last overall. Chaos Agent earned Glass Cannon for a single massive-scoring game and Equilibrium Finder even received the Participation Trophy. Stellar didn’t win a superlative but that reflects its balanced strategy; it wasn’t extreme in any single behavior but performed highly effectively across the board. In this environment, I would prioritize high total score over a high win rate. For example, Relationship Keeper had a higher win rate and won more matches but it scored fewer points per game on average comparing to Stellar. An agent that consistently earns high points across all matches will rank higher than one that simply wins more often. This shows that consistent scoring, even in some losses, is more valuable than frequent wins alone. For future designs, focusing on strategies that maximize points across a variety of opponents would likely outperform an agent that only aims to win individual matches.
#
# This tournament also reinforced the importance of iterative design, testing and balance. Stellar was trained on only 10 random opponents in Unit 5, yet it faced 20+ mostly unseen agents in this tournament. Despite this, it performed exceptionally well, showing that balanced strategies generalize effectively. If I were to redesign Stellar for this environment, one area I’d focus on is adaptive learning within the tournament itself, allowing the agent to track opponent tendencies early and adjust cooperation thresholds dynamically. Longer memory windows or probabilistic forgiveness could also help Stellar exploit patterns in opponents’ behaviors without becoming exploitable itself. These changes could improve performance in mixed populations and further increase total points.
#
# From a game theory perspective, the tournament makes it clear that there isn’t a single “best” strategy that beats everyone. Stellar performed well because it balanced cooperation and retaliation but Relationship Keeper and King Kong each dominated in certain matchups. The effectiveness of any strategy depends on the diversity of opponents. Purely aggressive agents excel against cooperative opponents but struggle against grudging or adaptive agents, while purely cooperative agents may score steadily but miss opportunities to maximize points. This mirrors classic concepts like tit-for-tat and iterated prisoner's dilemma, where the optimal strategy often depends on opponent mix rather than a single formula. These dynamics also reflect real-world scenarios where success depends on balancing risk, cooperation and adaptability. For instance, in financial markets, businesses must cooperate or compete depending on market conditions; in team projects, individuals must collaborate while defending against free riders; and in negotiations, strategic retaliation or forgiveness can determine long-term outcomes. The tournament’s repeated interactions and mixed strategies highlight how flexible, adaptive approaches often outperform rigid, extreme strategies over time.
